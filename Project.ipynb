# %% [markdown]
# # Exploration of the data

# %%
data <- read.csv(file.path("C:/Users/camil/Desktop/notebooks-bio322/data/epfl-bio-322a/training_data.csv"))
#Exploration:
data
dim(data)
str(data)
names(data)
#par(mfcol=c(1,3), cex=.7)
plot(data$complexity.from.pubmed, data$VALENCE.PLEASANTNESS, xlab= "Complexity from pubmed [unit ?]", ylab="Valence pleasantness [unit ?]")
#data$VALENCE.PLEASANTNESS50 <- data$VALENCE.PLEASANTNESS > 50
#plot(data$MW[data$VALENCE.PLEASANTNESS50], data$AMW[data$VALENCE.PLEASANTNESS50], col='red', ylab='AMW', xlab='MW')
#points(data$MW[!data$VALENCE.PLEASANTNESS50], data$AMW[!data$VALENCE.PLEASANTNESS50],
       #col = "blue", ylab = "AMW", xlab = "MW")
#legend("bottomright", legend = c("<= 70", "> 70"),
       #col = c("blue", "red"), pch='o') #pch indique les caractères pour la légende : points
# Out:
#     Intensity VALENCE.PLEASANTNESS SWEETORSOUR complexity.from.pubmed MW
# 1   low       45                   FALSE       302.0                  208.33
# 2   high      49                    TRUE        72.6                  122.18
# 3   high      56                    TRUE       259.0                  242.29
# 4   high       7                   FALSE        56.6                   88.12
# 5   low       51                   FALSE        84.7                  136.21
# 6   high      21                   FALSE       160.0                  192.28
# 7   low       56                   FALSE       116.0                  170.22
# 8   low       52                   FALSE        25.0                  114.26
# 9   low       53                    TRUE       355.0                  268.30
# 10  low        1                   FALSE        68.4                  152.26
# 11  low        9                   FALSE       155.0                  148.17
# ...
